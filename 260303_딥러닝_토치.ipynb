# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
print(tf.test.gpu_device_name())
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# /device:GPU:0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772497529.430066    7465 gpu_device.cc:2020] Created device /device:GPU:0 with 3620 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
